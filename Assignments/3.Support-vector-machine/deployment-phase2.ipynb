# %%
import pickle

load_model = pickle.load(open('finalized_model_svm.sav','rb'))
result=load_model.predict([[165349.20,136897.80,471784.10,0,1]])
result
# Out:
# C:\Users\rajalakshmi.thandava\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([196888.06734872])

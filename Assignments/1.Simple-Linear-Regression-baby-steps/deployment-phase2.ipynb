# %%
#Here we import a Pickle a library to perform load the model into the variable from the file

import pickle

loaded_model=pickle.load(open("finalized_model_linear.sav","rb"))
result=loaded_model.predict([[0]])#give the test value to the loaded model to test
# Out:
# C:\Users\rajalakshmi.thandava\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
